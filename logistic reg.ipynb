# %% [markdown]
# ## Import Libraries

# %% [markdown]
# ### Lets import some libs to get started

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %% [markdown]
# ## Data

# %% [markdown]
# ### Lets start reading titanic csv file into a pandas dataframe

# %% [markdown]
# #### train

# %%
train=pd.read_csv("titanic_train.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## EDA >> Exploratory Data Analysis

# %% [markdown]
# ### lets begin with checking out missing data!

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(train.isnull(),cmap="viridis",yticklabels=False)
# Out:
# <Axes: >

# %%
sns.countplot(x="Survived",data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Sex",data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Pclass",data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
train["Age"].hist(bins=30)
# Out:
# <Axes: >

# %%
sns.distplot(train["Age"].dropna(),kde=False)
# Out:
# C:\Users\School\AppData\Local\Temp\ipykernel_19248\756929560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train["Age"].dropna(),kde=False)
# <Axes: xlabel='Age'>

# %%
sns.countplot(x="SibSp",data=train)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.boxplot(x="Pclass",y="Age",data=train)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
def impute_age(cols):
    """Imputing for Age feature 

    Args:
        cols (Numeric): 2 cols will be passed to be inside the function 
    """
    Age=cols[0]
    Pclass=cols[1]
    
    if pd.isnull(Age):
        if Pclass==1:
            return 38
        elif Pclass==2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
train[["Age","Pclass"]]
# Out:
#       Age  Pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
train["Age"]=train[["Age","Pclass"]].apply(impute_age,axis=1)
# Out:
# C:\Users\School\AppData\Local\Temp\ipykernel_19248\1029027436.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Age=cols[0]
# C:\Users\School\AppData\Local\Temp\ipykernel_19248\1029027436.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pclass=cols[1]

# %%
sns.heatmap(train.isnull())
# Out:
# <Axes: >

# %%
train.drop("Cabin",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 train.drop("Cabin",axis=1,inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
train["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
train["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sex=pd.get_dummies(train["Sex"],drop_first=True)

# %%
sex
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
embark=pd.get_dummies(train["Embarked"],drop_first=True)

# %%
embark
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 2 columns]

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.drop(["Sex","Embarked","Name","Ticket","PassengerId"],axis=1,inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
train=pd.concat([train,sex,embark],axis=1)

# %%
train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0           0       3  22.0      1      0   7.2500   True  False   True
# 1           1       1  38.0      1      0  71.2833  False  False  False
# 2           1       3  26.0      0      0   7.9250  False  False   True
# 3           1       1  35.0      1      0  53.1000  False  False   True
# 4           0       3  35.0      0      0   8.0500   True  False   True
# ..        ...     ...   ...    ...    ...      ...    ...    ...    ...
# 886         0       2  27.0      0      0  13.0000   True  False   True
# 887         1       1  19.0      0      0  30.0000  False  False   True
# 888         0       3  24.0      1      2  23.4500  False  False   True
# 889         1       1  26.0      0      0  30.0000   True  False  False
# 890         0       3  32.0      0      0   7.7500   True   True  False
#
# [891 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0           0       3  22.0      1      0   7.2500   True  False   True
# 1           1       1  38.0      1      0  71.2833  False  False  False
# 2           1       3  26.0      0      0   7.9250  False  False   True
# 3           1       1  35.0      1      0  53.1000  False  False   True
# 4           0       3  35.0      0      0   8.0500   True  False   True
# ..        ...     ...   ...    ...    ...      ...    ...    ...    ...
# 886         0       2  27.0      0      0  13.0000   True  False   True
# 887         1       1  19.0      0      0  30.0000  False  False   True
# 888         0       3  24.0      1      2  23.4500  False  False   True
# 889         1       1  26.0      0      0  30.0000   True  False  False
# 890         0       3  32.0      0      0   7.7500   True   True  False
#
# [891 rows x 9 columns]

# %%
X_train,Xtest,y_train,y_test=train_test_split(train.drop("Survived",axis=1),train["Survived"],test_size=.20,random_state=1000)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\School\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
ypred=logmodel.predict(Xtest)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       100
#            1       0.80      0.72      0.76        79
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179
